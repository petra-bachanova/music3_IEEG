# %% [markdown]
# ---
# ---
#
# # iEEG PREPROCESSING PIPELINE
# ### Dartmouth ECoG Lab
# #### version 1 (2021)
# #### version 2 (2024) - CC edits
# #### version 3 (2024) - PB edits
#
# ---
# ---

# %%
### libraries
import pandas as pd
import mne
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
#from mne import io, read_proj, read_custom_montage
from mne import io, read_proj
from mne.channels import read_custom_montage
from mne.datasets import sample
#from mne.time_frequency import psd_multitaper
from mne.time_frequency import psd_array_multitaper
import re 
from scipy import stats
from time import time
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import os
import glob
import datetime
import re

# %%
### 1. LOAD DATA:
# Load iEEG file
subject = "Mus26" ################################################## CHANGE: SUBJECT NAME
run = "1" ################################################## CHANGE: RUN #
project_dir = re.sub("/Code/Preprocessing", "", os.getcwd())

pathEDF = glob.glob(project_dir + '/Data/EDF files/' + subject + '*run' + run + '*.edf')[0]  # glob.glob finds partial string match
raw = mne.io.read_raw_edf(pathEDF, preload=True)
mne.set_log_level("WARNING")

# iEEG file info:
print('Data type: {}\n\n{}\n'.format(type(raw), raw))
print('Sample rate:', raw.info['sfreq'], 'Hz') # Get the sample rate
print('Size of the matrix: {}\n'.format(raw.get_data().shape)) # Get the size of the matrix
# print(raw.info) # VIEW INFO SUMMARY OF EEG DATA
# print('The actual data is just a matrix array!\n\n {}\n'.format(raw.get_data()))
# Out:
# Extracting EDF parameters from /Users/Petra/Documents/repos/music3_IEEG_local/Data/EDF files/Mus26_clip_run1_BF_deidentified.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2333311  =      0.000 ...  4557.248 secs...
# Data type: <class 'mne.io.edf.edf.RawEDF'>
#
# <RawEDF | Mus26_clip_run1_BF_deidentified.edf, 276 x 2333312 (4557.2 s), ~4.80 GB, data loaded>
#
# Sample rate: 512.0 Hz
# Size of the matrix: (276, 2333312)

# %%
#plt.ion() #Makes plot interactive
#plt.switch_backend('TkAgg')
#mpl.use('Qt5Agg')
# %matplotlib qt
raw.plot()
#INTRUCTIONS: Press Esc to exit once bad channels have been selected
# Out:
# <MNEBrowseFigure size 2112x1600 with 4 Axes>

# %%
raw.plot_psd(tmax=np.inf, average=False)
# Out:
# <MNELineFigure size 2000x700 with 1 Axes>

# %%
### 2. CLEAN DATA:
np.bool = np.bool_ #https://stackoverflow.com/questions/74893742/how-to-solve-attributeerror-module-numpy-has-no-attribute-bool
def cleaner(raw):
    """
    iEEG PREPROCESSING PIPELINE
    INPUT: RAW iEEG (MNE)
    OUTPUT: CLEANED iEEG ('picks')
    # note: resampling should already be based on a filtered signal!
    # (i.e., first filtering, then down sampling)
    """
    ### 1. rereference data (average rereference)
    raw.set_eeg_reference('average', projection=True)
    # raw.plot_psd(area_mode='range', tmax=10.0) # visual verification
    #raw.plot_psd(area_mode='range', tmax=10.0) # visual verification

    print('Original sampling rate:', raw.info['sfreq'], 'Hz')

    ### 2. notch filter
    raw = raw.notch_filter(np.arange(60, int(raw.info['sfreq']/2)-1, 60), filter_length='auto', phase='zero') # 60, 241, 60
    # raw.plot_psd(tmin=tmin, tmax=tmax, fmin=fmin, fmax=fmax, n_fft=n_fft,
    #              n_jobs=1, proj=True, ax=ax, color=(1, 0, 0), picks=picks) # visual verification
    #raw.plot_psd(tmin=tmin, tmax=tmax, fmin=fmin, fmax=fmax, n_fft=n_fft,
    #              n_jobs=1, proj=True, ax=ax, color=(1, 0, 0), picks=picks) # visual verification

    ### 3. other filters 
    # low pass filter (250Hz)
    raw = raw.filter(None, 250., h_trans_bandwidth='auto', filter_length='auto', phase='zero')
    # high pass filter (1Hz) - remove slow drifts
    raw = raw.filter(1., None, l_trans_bandwidth='auto', filter_length='auto', phase='zero')
    # raw.plot_psd(area_mode='range', tmax=10.0) # visual verification
    #raw.plot_psd(area_mode='range', tmax=10.0) # visual verification


    ### 4. downsampling (200Hz)
    raw = raw.resample(200, npad='auto')
    print('New sampling rate:', raw.info['sfreq'], 'Hz')
    
    ### 5. reject bad channels
    def check_bads_adaptive(raw, picks, fun=np.var, thresh=3, max_iter=np.inf):
        ch_x = fun(raw[picks, :][0], axis=-1)
        my_mask = np.zeros(len(ch_x), dtype=np.bool)
        i_iter = 0
        while i_iter < max_iter:
            ch_x = np.ma.masked_array(ch_x, my_mask)
            this_z = stats.zscore(ch_x)
            local_bad = np.abs(this_z) > thresh
            my_mask = np.max([my_mask, local_bad], 0)
            print('iteration %i : total bads: %i' % (i_iter, sum(my_mask)))        
            if not np.any(local_bad): 
                break
            i_iter += 1
        bad_chs = [raw.ch_names[i] for i in np.where(ch_x.mask)[0]]
        return (bad_chs)
    # Find the first index of the super-bad channels
    endIndex = 1
    for i, name in enumerate(raw.info['ch_names']): # can add new logic to reject other channels that are definitely bad
        if len(re.compile(r'C\d{3}').findall(name)) > 0:
            endIndex = i
            break
    bad_chs = raw.ch_names[endIndex:]
    bad_chs.extend(check_bads_adaptive(raw, list(range(0,endIndex)), thresh=3)) 
    raw.info['bads'] = bad_chs
    #     print(bad_chs)
    #     print(len(raw.info['bads'])) # check which channels are marked as bad
    ### PICK ONLY GOOD CHANNELS:
    picks = raw.pick_types(eeg = True, meg = False, exclude = 'bads')
    print("NUMBER OF CHANNELS FOR SUBJECT {}: {}".format(subject,len(picks.info['chs'])))
    #     print("THIS SHOULD BE 0: {}".format(len(picks.info['bads'])) ) # check statement
    
    return (picks)

picks = cleaner(raw)
# Out:
# Original sampling rate: 512.0 Hz
# New sampling rate: 200.0 Hz
# iteration 0 : total bads: 0
# NUMBER OF CHANNELS FOR SUBJECT Mus26: 1

# %%
picks
# Out:
# <RawEDF | Mus26_clip_run1_BF_deidentified.edf, 1 x 911450 (4557.2 s), ~7.0 MB, data loaded>

# %%
# bad contacts from Brian's info file
info_file = pd.read_excel(f"{project_dir}/Data/music3_EDF_info.xlsx")
bad_channels_manual = info_file[(info_file["Music ID"] == subject) & (info_file["Run"] == int(run))]["Bad contacts"].values[0]
# if there are no manually marked bad channels, set as empty list
if str(bad_channels_manual) == 'nan':
    bad_channels_manual = []
else:
    bad_channels_manual = list(bad_channels_manual.split(", "))

# scalp EEG electrodes
scalp_eeg_electrodes = ['Fp1', 'FP1', 'Fp2', 'FP2', 'F7', 'F8', 'F3', 'F4', 'Fz', 'T3', 'T4', 'C3', 'C4', 'Cz', 'T5', 'T6', 'P3', 'P4', 'Pz', 'O1', 'O2']

# add scalp electrodes to bad_channels_manual (to be removed)
bad_channels_manual.extend(scalp_eeg_electrodes)
# check which ones are in patient's channels, add these to 'bad' channels along with those channels marked in the info files
channels_to_drop = set(picks.info["ch_names"]).intersection(bad_channels_manual)
picks.info['bads'].extend(channels_to_drop)

# %%
#https://mne.tools/stable/auto_tutorials/preprocessing/15_handling_bad_channels.html
print(picks.ch_names)
picks.plot()
# Out:
# ['LANT1']
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 3
#       1 #https://mne.tools/stable/auto_tutorials/preprocessing/15_handling_bad_channels.html
#       2 print(picks.ch_names)
# ----> 3 picks.plot()
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/io/base.py:1856, in BaseRaw.plot(self, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, show_scalebars, time_format, precompute, use_opengl, picks, theme, overview_mode, splash, verbose)
#    1815 @copy_function_doc_to_method_doc(plot_raw)
#    1816 def plot(
#    1817     self,
#    (...)
#    1854     verbose=None,
#    1855 ):
# -> 1856     return plot_raw(
#    1857         self,
#    1858         events,
#    1859         duration,
#    1860         start,
#    1861         n_channels,
#    1862         bgcolor,
#    1863         color,
#    1864         bad_color,
#    1865         event_color,
#    1866         scalings,
#    1867         remove_dc,
#    1868         order,
#    1869         show_options,
#    1870         title,
#    1871         show,
#    1872         block,
#    1873         highpass,
#    1874         lowpass,
#    1875         filtorder,
#    1876         clipping,
#    1877         show_first_samp,
#    1878         proj,
#    1879         group_by,
#    1880         butterfly,
#    1881         decim,
#    1882         noise_cov=noise_cov,
#    1883         event_id=event_id,
#    1884         show_scrollbars=show_scrollbars,
#    1885         show_scalebars=show_scalebars,
#    1886         time_format=time_format,
#    1887         precompute=precompute,
#    1888         use_opengl=use_opengl,
#    1889         picks=picks,
#    1890         theme=theme,
#    1891         overview_mode=overview_mode,
#    1892         splash=splash,
#    1893         verbose=verbose,
#    1894     )
#
# File <decorator-gen-203>:12, in plot_raw(raw, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, show_scalebars, time_format, precompute, use_opengl, picks, theme, overview_mode, splash, verbose)
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/viz/raw.py:409, in plot_raw(raw, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id, show_scrollbars, show_scalebars, time_format, precompute, use_opengl, picks, theme, overview_mode, splash, verbose)
#     354 precompute = _handle_precompute(precompute)
#     355 params = dict(
#     356     inst=raw,
#     357     info=info,
#    (...)
#     406     splash=splash,
#     407 )
# --> 409 fig = _get_browser(show=show, block=block, **params)
#     411 return fig
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/viz/_figure.py:698, in _get_browser(show, block, **kwargs)
#     695             return fig
#     697 # Initialize Browser
# --> 698 fig = backend._init_browser(**kwargs)
#     699 _show_browser(show=show, block=block, fig=fig)
#     701 return fig
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/viz/_mpl_figure.py:2482, in _init_browser(**kwargs)
#    2479 """Instantiate a new MNE browse-style figure."""
#    2480 from mne.io import BaseRaw
# -> 2482 fig = _figure(toolbar=False, FigureClass=MNEBrowseFigure, layout=None, **kwargs)
#    2484 # splash is ignored (maybe we could do it for mpl if we get_backend() and
#    2485 # check if it's Qt... but seems overkill)
#    2486
#    2487 # initialize zen mode
#    2488 # (can't do in __init__ due to get_position() calls)
#    2489 fig.canvas.draw()
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/viz/_mpl_figure.py:2365, in _figure(toolbar, FigureClass, **kwargs)
#    2363 rc = dict() if toolbar else dict(toolbar="none")
#    2364 with rc_context(rc=rc):
# -> 2365     fig = plt.figure(FigureClass=FigureClass, **kwargs)
#    2366 # BACKEND defined globally at the top of this file
#    2367 fig.mne.backend = BACKEND
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/matplotlib/pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     924 if len(allnums) == max_open_warning >= 1:
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# --> 934 manager = new_figure_manager(
#     935     num, figsize=figsize, dpi=dpi,
#     936     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     937     FigureClass=FigureClass, **kwargs)
#     938 fig = manager.canvas.figure
#     939 if fig_label:
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/matplotlib/pyplot.py:465, in new_figure_manager(*args, **kwargs)
#     463 """Create a new figure manager instance."""
#     464 _warn_if_gui_out_of_main_thread()
# --> 465 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/matplotlib/backend_bases.py:3410, in _Backend.new_figure_manager(cls, num, *args, **kwargs)
#    3408 from matplotlib.figure import Figure
#    3409 fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3410 fig = fig_cls(*args, **kwargs)
#    3411 return cls.new_figure_manager_given_figure(num, fig)
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/viz/_mpl_figure.py:379, in MNEBrowseFigure.__init__(self, inst, figsize, ica, xlabel, **kwargs)
#     375 self.backend_name = "matplotlib"
#     377 kwargs.update({"inst": inst, "figsize": figsize, "ica": ica, "xlabel": xlabel})
# --> 379 BrowserBase.__init__(self, **kwargs)
#     380 MNEFigure.__init__(self, **kwargs)
#     382 # MAIN AXES: default sizes (inches)
#     383 # XXX simpler with constrained_layout? (when it's no longer "beta")
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/viz/_figure.py:153, in BrowserBase.__init__(self, **kwargs)
#     151 self._update_picks()
#     152 if not self.mne.instance_type == "ica":
# --> 153     self._update_projector()
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/viz/_figure.py:212, in BrowserBase._update_projector(self)
#     210     self.mne.info["projs"] = [deepcopy(self.mne.projs[ix]) for ix in inds]
#     211 # compute the projection operator
# --> 212 proj, wh_chs = _setup_plot_projector(
#     213     self.mne.info, self.mne.noise_cov, True, self.mne.use_noise_cov
#     214 )
#     215 self.mne.whitened_ch_names = list(wh_chs)
#     216 self.mne.projector = proj
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/viz/utils.py:2031, in _setup_plot_projector(info, noise_cov, proj, use_noise_cov, nave)
#    2029         projector[nan_picks] = np.nan
#    2030 elif proj:
# -> 2031     projector, _ = setup_proj(info, add_eeg_ref=False, verbose=False)
#    2032 return projector, whitened_ch_names
#
# File <decorator-gen-18>:10, in setup_proj(info, add_eeg_ref, activate, eeg_ref_ch_type, verbose)
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/_fiff/proj.py:1164, in setup_proj(info, add_eeg_ref, activate, eeg_ref_ch_type, verbose)
#    1161     info["projs"].append(eeg_proj)
#    1163 # Create the projector
# -> 1164 projector, nproj = make_projector_info(info)
#    1165 if nproj == 0:
#    1166     if verbose:
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/_fiff/proj.py:928, in make_projector_info(info, include_active)
#     909 @fill_doc
#     910 def make_projector_info(info, include_active=True):
#     911     """Make an SSP operator using the measurement info.
#     912
#     913     Calls make_projector on good channels.
#    (...)
#     926         How many items in the projector.
#     927     """
# --> 928     proj, nproj, _ = make_projector(
#     929         info["projs"], info["ch_names"], info["bads"], include_active
#     930     )
#     931     return proj, nproj
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/_fiff/proj.py:768, in make_projector(projs, ch_names, bads, include_active)
#     742 def make_projector(projs, ch_names, bads=(), include_active=True):
#     743     """Create an SSP operator from SSP projection vectors.
#     744
#     745     Parameters
#    (...)
#     766         The orthogonal basis of the projection vectors.
#     767     """
# --> 768     return _make_projector(projs, ch_names, bads, include_active)
#
# File /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/_fiff/proj.py:884, in _make_projector(projs, ch_names, bads, include_active, inplace)
#     882 proj = np.eye(nchan, nchan) - np.dot(U, U.T)
#     883 if nproj >= nchan:  # e.g., 3 channels and 3 projectors
# --> 884     raise RuntimeError(
#     885         "Application of %d projectors for %d channels "
#     886         "will yield no components." % (nproj, nchan)
#     887     )
#     889 return proj, nproj, U
#
# RuntimeError: Application of 1 projectors for 1 channels will yield no components.

# %%
#RUN TWICE TO ENSURE BAD CHANNELS HAVE BEEN REMOVED
print(f"Bad channels: {picks.info['bads']}")
print(f"Good channels: {picks.ch_names}")
print(f"# bad channels: {len(picks.info['bads'])}\n# good channels: {len(picks.ch_names)}")
picks = picks.pick_types(eeg = True, meg = False, exclude='bads')
# Out:
# Bad channels: []
# Good channels: ['LANT1']
# # bad channels: 0
# # good channels: 1

# %%
print(picks.get_data().T.shape)
# Out:
# (907150, 108)

# %%
### EXPORT DATA:
# export picks as .csv
today = datetime.datetime.today().strftime("%y%m%d")
header = ','.join(picks.ch_names)
np.savetxt(f"{project_dir}/Data/Preprocessed/{subject}_run{run}_IEEG_{today}.csv", picks.get_data().T, delimiter=',', header=header)

# %% [markdown]
# # END
