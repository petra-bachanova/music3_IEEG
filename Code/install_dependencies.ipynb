# %% [markdown]
# ### Install dependencies from requirements.txt files
# Use the shellscript below. Should be enough to run once.

# %%
# %%bash
#
# PROJECT_DIR="/dartfs-hpc/rc/lab/E/ECoG/music3_IEEG"
# # Define the path to the requirements.txt file
# REQUIREMENTS_FILE="$PROJECT_DIR/Code/requirements.txt"
#
# # Attempt to install each package listed in requirements.txt
# echo "Attempting to install packages from $REQUIREMENTS_FILE"
#
# # Read each line (package) from the requirements file and install it
# while IFS= read -r PACKAGE; do
#     echo "Attempting to install package: $PACKAGE"
#     # Try installing via conda first
#     if conda install --yes $PACKAGE; then
#         echo "Installation of $PACKAGE via conda successful!"
#     else
#         # If conda installation fails, try installing via pip
#         echo "Package $PACKAGE not found on conda"
#     fi
# done < "$REQUIREMENTS_FILE"
# Out:
# process started
# /dartfs-hpc/rc/lab/E/ECoG/music3_IEEG
# /dartfs-hpc/rc/lab/E/ECoG/music3_IEEG/Code/requirements.txt
# Attempting to install packages from /dartfs-hpc/rc/lab/E/ECoG/music3_IEEG/Code/requirements.txt
# Attempting to install package: pandas
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Installation of pandas via conda successful!
# Attempting to install package: numpy
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Installation of numpy via conda successful!
# Attempting to install package: scikit-learn
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Installation of scikit-learn via conda successful!
# Attempting to install package: matplotlib
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Installation of matplotlib via conda successful!
# Attempting to install package: scipy
# ...

# %%
import openpyxl

# %%
# !pip install torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 21.4 MB/s eta 0:00:0000:0100:01
# ...
